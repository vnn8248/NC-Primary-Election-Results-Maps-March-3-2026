# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
RESULTS_FILE = (
    PROJECT_ROOT
    / "data"
    / "raw"
    / "results"
    / "nc_primary_election_results_pct_20260303_RAW.csv"
)

# %%
SHAPEFILE = (
    PROJECT_ROOT
    / "data"
    / "raw"
    / "geography"
    / "SBE_PRECINCTS_20251212"
    / "SBE_PRECINCTS_20251212.shp"
)

# %%
CROSSWALK_FILE = (
    PROJECT_ROOT
    / "data"
    / "crosswalks"
    / "precinct_crosswalk_2026.csv"
)

# %%
import pandas as pd

CROSSWALK_DF = pd.read_csv(CROSSWALK_FILE)

# %%
contest_name="NC STATE SENATE DISTRICT 18 (REP)"

# %%
import pydash


WEB_FILE = (
    PROJECT_ROOT
    / "map"
    / "data"
    / f"{pydash.snake_case(contest_name)}.geojson"
)

# %%
CONTEST_SUMMARY_FILE = (
    PROJECT_ROOT
    / "data"
    / "processed"
    / f"{pydash.snake_case(contest_name)}_contest_summary.csv"
)

# %%
WEB_COLUMNS = [
    "county",
    "precinct",
    "enr_desc",
    "winner",
    "winner_votes",
    "winner_share",
    "runner_up",
    "runner_up_votes",
    "runner_up_share",
    "contest_votes",
    "margin_of_victory",
    "is_tie",
    "results",
    "participated",
    "map_key",
    "geometry"
]

# %%
from pipelines.district import build_district_map

# %%
web_precincts = build_district_map(
    results_file=RESULTS_FILE,
    geography_file=SHAPEFILE,
    crosswalk=CROSSWALK_DF,
    contest_name=contest_name,
    contest_summary_file=CONTEST_SUMMARY_FILE,
    output_file=WEB_FILE,
    web_columns=WEB_COLUMNS,
)

# %%
participated = web_precincts[
    web_precincts["participated"]
].copy()

west, south, east, north = participated.total_bounds

contest_bounds = [
    [west, south],
    [east, north]
]

print(contest_bounds)
# Out:
# [[np.float64(-78.80762299092058), np.float64(35.783509999663366)], [np.float64(-78.25371099138387), np.float64(36.54254100036947)]]

# %%
web_precincts
# Out:
#     county precinct enr_desc winner  winner_votes  winner_share runner_up  \
# 0      NaN      NaN    01-05    NaN           NaN           NaN       NaN
# 1      NaN      NaN    01-09    NaN           NaN           NaN       NaN
# 2      NaN      NaN    01-01    NaN           NaN           NaN       NaN
# 3      NaN      NaN    01-02    NaN           NaN           NaN       NaN
# 4      NaN      NaN    01-03    NaN           NaN           NaN       NaN
# ..     ...      ...      ...    ...           ...           ...       ...
# 226    NaN      NaN    13-12    NaN           NaN           NaN       NaN
# 227    NaN      NaN    12-12    NaN           NaN           NaN       NaN
# 228    NaN      NaN    12-13    NaN           NaN           NaN       NaN
# 229    NaN      NaN    05-09    NaN           NaN           NaN       NaN
# 230    NaN      NaN    05-10    NaN           NaN           NaN       NaN
#
#      runner_up_votes  runner_up_share  contest_votes  margin_of_victory  \
# 0                NaN              NaN            NaN                NaN
# 1                NaN              NaN            NaN                NaN
# 2                NaN              NaN            NaN                NaN
# 3                NaN              NaN            NaN                NaN
# 4                NaN              NaN            NaN                NaN
# ..               ...              ...            ...                ...
# 226              NaN              NaN            NaN                NaN
# 227              NaN              NaN            NaN                NaN
# 228              NaN              NaN            NaN                NaN
# 229              NaN              NaN            NaN                NaN
# 230              NaN              NaN            NaN                NaN
#
#      is_tie results  participated map_key  \
# 0     False     NaN         False     NaN
# 1     False     NaN         False     NaN
# 2     False     NaN         False     NaN
# 3     False     NaN         False     NaN
# 4     False     NaN         False     NaN
# ..      ...     ...           ...     ...
# 226   False     NaN         False     NaN
# 227   False     NaN         False     NaN
# 228   False     NaN         False     NaN
# 229   False     NaN         False     NaN
# 230   False     NaN         False     NaN
#
#                                               geometry
# 0    POLYGON ((-78.64603 35.80064, -78.64604 35.800...
# 1    POLYGON ((-78.63972 35.79958, -78.64013 35.799...
# 2    POLYGON ((-78.66134 35.78646, -78.66134 35.786...
# 3    POLYGON ((-78.67302 35.79209, -78.67303 35.791...
# 4    POLYGON ((-78.67493 35.80105, -78.67517 35.801...
# ..                                                 ...
# 226  POLYGON ((-78.58991 35.8552, -78.58969 35.8552...
# 227  POLYGON ((-78.75004 35.61572, -78.75081 35.615...
# 228  POLYGON ((-78.77322 35.58893, -78.77326 35.589...
# 229  POLYGON ((-78.83991 35.8183, -78.84034 35.8182...
# 230  POLYGON ((-78.87199 35.82074, -78.87206 35.820...
#
# [231 rows x 16 columns]
