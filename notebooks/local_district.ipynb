# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
# %load_ext autoreload
# %autoreload 2

# %%
RESULTS_FILE = (
    PROJECT_ROOT
    / "data"
    / "raw"
    / "results"
    / "nc_primary_election_results_pct_20260303_RAW.csv"
)

# %%
SHAPEFILE = (
    PROJECT_ROOT
    / "data"
    / "raw"
    / "geography"
    / "SBE_PRECINCTS_20251212"
    / "SBE_PRECINCTS_20251212.shp"
)

# %%
CROSSWALK_FILE = (
    PROJECT_ROOT
    / "data"
    / "crosswalks"
    / "precinct_crosswalk_2026.csv"
)

# %%
import pandas as pd

CROSSWALK_DF = pd.read_csv(CROSSWALK_FILE)

# %%
contest_name="DURHAM COUNTY BOARD OF EDUCATION DISTRICT 02"
county="DURHAM"

# %%
import pydash


WEB_FILE = (
    PROJECT_ROOT
    / "map_data"
    / f"{pydash.snake_case(contest_name)}.geojson"
)

# %%
CONTEST_SUMMARY_FILE = (
    PROJECT_ROOT
    / "data"
    / "processed"
    / f"{pydash.snake_case(contest_name)}_contest_summary.csv"
)

# %%
WEB_COLUMNS = [
    "county",
    "precinct",
    "enr_desc",
    "winner",
    "winner_votes",
    "winner_share",
    "runner_up",
    "runner_up_votes",
    "runner_up_share",
    "contest_votes",
    "margin_of_victory",
    "is_tie",
    "results",
    "participated",
    "map_key",
    "geometry"
]

# %%
from pipelines.local_district import build_local_district_map

# %%
web_precincts = build_local_district_map(
    results_file=RESULTS_FILE,
    geography_file=SHAPEFILE,
    crosswalk=CROSSWALK_DF,
    contest_name=contest_name,
    contest_summary_file=CONTEST_SUMMARY_FILE,
    county=county,
    output_file=WEB_FILE,
    web_columns=WEB_COLUMNS,
)

# %%
participated = web_precincts[
    web_precincts["participated"]
].copy()

west, south, east, north = participated.total_bounds

contest_bounds = [
    [west, south],
    [east, north]
]

print(contest_bounds)
# Out:
# [[np.float64(-78.9583799916683), np.float64(35.90250000038127)], [np.float64(-78.8857599916494), np.float64(36.03723999993787)]]

# %%
web_precincts
# Out:
#     county precinct                        enr_desc           winner  \
# 0      NaN      NaN           Triangle Grace Church              NaN
# 1   DURHAM        7              School Of The Arts       Nadeen Bir
# 2   DURHAM       12        Monument Of Faith Church       Nadeen Bir
# 3   DURHAM        1           Brogden Middle School       Nadeen Bir
# 4   DURHAM        4      School Of Science And Math       Nadeen Bir
# 5   DURHAM        2         George Watts Elementary       Nadeen Bir
# 6   DURHAM     34-1          Pearsontown Elementary       Nadeen Bir
# 7   DURHAM        3             E K Powe Elementary       Nadeen Bir
# 8   DURHAM        5            Patterson Rec Center       Nadeen Bir
# 9      NaN      NaN                 Lakewood School              NaN
# 10  DURHAM        8             Morehead Montessori       Nadeen Bir
# 11     NaN      NaN           Bethesda Ruritan Club              NaN
# 12     NaN      NaN              Neal Middle School              NaN
# 13  DURHAM        9         Forest Hills Club House       Nadeen Bir
# 14  DURHAM       10            C C Spaulding School       Nadeen Bir
# 15     NaN      NaN            First United Antioch              NaN
# 16     NaN      NaN               Burton Elementary              NaN
# 17  DURHAM       20    County Agricultural Building       Nadeen Bir
# 18     NaN      NaN                Y E Smith School              NaN
# 19     NaN      NaN               Mt Calvary Church              NaN
# 20  DURHAM       17             County Main Library       Nadeen Bir
# 21     NaN      NaN          American Legion Post 7              NaN
# 22  DURHAM       21           Club Boulevard School       Nadeen Bir
# 23     NaN      NaN                   Vfw Post 2740              NaN
# 24     NaN      NaN            Yates Baptist Church              NaN
# 25     NaN      NaN                Cole Mill Church              NaN
# 26     NaN      NaN                The River Church              NaN
# 27     NaN      NaN    Dps Staff Development Center              NaN
# 28  DURHAM       42          Shephard Magnet School       Nadeen Bir
# 29     NaN      NaN           Temple Baptist Church              NaN
# 30     NaN      NaN            Northern High School              NaN
# 31     NaN      NaN  Bahama Vfd - Rougemont Station              NaN
# 32     NaN      NaN            Creekside Elementary              NaN
# 33     NaN      NaN        Holmes Recreation Center              NaN
# 34     NaN      NaN             Bahama Ruritan Club              NaN
# 35     NaN      NaN                Glenn Elementary              NaN
# 36     NaN      NaN            Southern High School              NaN
# 37  DURHAM     34-2            Ivy Community Center       Nadeen Bir
# 38  DURHAM       54          Waterford Village Apts       Nadeen Bir
# 39  DURHAM    55-11                          055-11       Nadeen Bir
# 40  DURHAM    55-49                          055-49  Bettina Umstead
# 41     NaN      NaN             Hope Valley Baptist              NaN
# 42     NaN      NaN       Rogers-Herr Middle School              NaN
# 43  DURHAM       41       White Rock Baptist Church       Nadeen Bir
# 44     NaN      NaN          Forest View Elementary              NaN
# 45     NaN      NaN          North Regional Library              NaN
# 46     NaN      NaN           Edison Johnson Center              NaN
# 47     NaN      NaN       Mcmannen United Methodist              NaN
# 48     NaN      NaN            Southwest Elementary              NaN
# 49     NaN      NaN         Evangel Assembly Of God              NaN
# 50     NaN      NaN                 Triangle Church              NaN
# 51     NaN      NaN                            30-3              NaN
# 52     NaN      NaN                            30-4              NaN
# 53     NaN      NaN                            33-1              NaN
# 54     NaN      NaN                            33-2              NaN
# 55     NaN      NaN                            35-4              NaN
# 56     NaN      NaN                            35-5              NaN
# 57     NaN      NaN                              56              NaN
#
#     winner_votes  winner_share        runner_up  runner_up_votes  \
# 0            NaN           NaN              NaN              NaN
# 1          296.0     68.837209  Bettina Umstead             81.0
# 2           53.0     54.081633  Bettina Umstead             37.0
# 3          110.0     51.401869  Bettina Umstead             61.0
# 4          342.0     63.333333     Rachel Waltz            126.0
# 5          307.0     68.374165  Bettina Umstead             86.0
# 6          325.0     69.148936  Bettina Umstead            112.0
# 7          276.0     60.927152     Rachel Waltz            102.0
# 8          118.0     55.924171  Bettina Umstead             64.0
# 9            NaN           NaN              NaN              NaN
# 10         361.0     74.741201  Bettina Umstead             79.0
# 11           NaN           NaN              NaN              NaN
# 12           NaN           NaN              NaN              NaN
# 13         427.0     65.793529  Bettina Umstead            157.0
# 14         171.0     61.071429  Bettina Umstead             89.0
# 15           NaN           NaN              NaN              NaN
# 16           NaN           NaN              NaN              NaN
# 17         354.0     70.800000  Bettina Umstead             88.0
# 18           NaN           NaN              NaN              NaN
# 19           NaN           NaN              NaN              NaN
# 20         351.0     70.481928  Bettina Umstead             87.0
# 21           NaN           NaN              NaN              NaN
# 22         383.0     73.371648  Bettina Umstead            100.0
# 23           NaN           NaN              NaN              NaN
# 24           NaN           NaN              NaN              NaN
# 25           NaN           NaN              NaN              NaN
# 26           NaN           NaN              NaN              NaN
# 27           NaN           NaN              NaN              NaN
# 28         136.0     77.714286  Bettina Umstead             34.0
# 29           NaN           NaN              NaN              NaN
# 30           NaN           NaN              NaN              NaN
# 31           NaN           NaN              NaN              NaN
# 32           NaN           NaN              NaN              NaN
# 33           NaN           NaN              NaN              NaN
# 34           NaN           NaN              NaN              NaN
# 35           NaN           NaN              NaN              NaN
# 36           NaN           NaN              NaN              NaN
# 37         408.0     58.789625  Bettina Umstead            236.0
# 38         530.0     66.666667  Bettina Umstead            193.0
# 39          93.0     48.947368  Bettina Umstead             80.0
# 40          36.0     57.142857       Nadeen Bir             20.0
# 41           NaN           NaN              NaN              NaN
# 42           NaN           NaN              NaN              NaN
# 43         102.0     46.788991  Bettina Umstead             97.0
# 44           NaN           NaN              NaN              NaN
# 45           NaN           NaN              NaN              NaN
# 46           NaN           NaN              NaN              NaN
# 47           NaN           NaN              NaN              NaN
# 48           NaN           NaN              NaN              NaN
# 49           NaN           NaN              NaN              NaN
# 50           NaN           NaN              NaN              NaN
# 51           NaN           NaN              NaN              NaN
# 52           NaN           NaN              NaN              NaN
# 53           NaN           NaN              NaN              NaN
# 54           NaN           NaN              NaN              NaN
# 55           NaN           NaN              NaN              NaN
# 56           NaN           NaN              NaN              NaN
# 57           NaN           NaN              NaN              NaN
#
#     runner_up_share  contest_votes  margin_of_victory  is_tie  \
# 0               NaN            NaN                NaN   False
# 1         18.837209          430.0          50.000000   False
# 2         37.755102           98.0          16.326531   False
# 3         28.504673          214.0          22.897196   False
# 4         23.333333          540.0          40.000000   False
# 5         19.153675          449.0          49.220490   False
# 6         23.829787          470.0          45.319149   False
# 7         22.516556          453.0          38.410596   False
# 8         30.331754          211.0          25.592417   False
# 9               NaN            NaN                NaN   False
# 10        16.356108          483.0          58.385093   False
# 11              NaN            NaN                NaN   False
# 12              NaN            NaN                NaN   False
# 13        24.191063          649.0          41.602465   False
# 14        31.785714          280.0          29.285714   False
# 15              NaN            NaN                NaN   False
# 16              NaN            NaN                NaN   False
# 17        17.600000          500.0          53.200000   False
# 18              NaN            NaN                NaN   False
# 19              NaN            NaN                NaN   False
# 20        17.469880          498.0          53.012048   False
# 21              NaN            NaN                NaN   False
# 22        19.157088          522.0          54.214559   False
# 23              NaN            NaN                NaN   False
# 24              NaN            NaN                NaN   False
# 25              NaN            NaN                NaN   False
# 26              NaN            NaN                NaN   False
# 27              NaN            NaN                NaN   False
# 28        19.428571          175.0          58.285714   False
# 29              NaN            NaN                NaN   False
# 30              NaN            NaN                NaN   False
# 31              NaN            NaN                NaN   False
# 32              NaN            NaN                NaN   False
# 33              NaN            NaN                NaN   False
# 34              NaN            NaN                NaN   False
# 35              NaN            NaN                NaN   False
# 36              NaN            NaN                NaN   False
# 37        34.005764          694.0          24.783862   False
# 38        24.276730          795.0          42.389937   False
# 39        42.105263          190.0           6.842105   False
# 40        31.746032           63.0          25.396825   False
# 41              NaN            NaN                NaN   False
# 42              NaN            NaN                NaN   False
# 43        44.495413          218.0           2.293578   False
# 44              NaN            NaN                NaN   False
# 45              NaN            NaN                NaN   False
# 46              NaN            NaN                NaN   False
# 47              NaN            NaN                NaN   False
# 48              NaN            NaN                NaN   False
# 49              NaN            NaN                NaN   False
# 50              NaN            NaN                NaN   False
# 51              NaN            NaN                NaN   False
# 52              NaN            NaN                NaN   False
# 53              NaN            NaN                NaN   False
# 54              NaN            NaN                NaN   False
# 55              NaN            NaN                NaN   False
# 56              NaN            NaN                NaN   False
# 57              NaN            NaN                NaN   False
#
#                                               results  participated  \
# 0                                                 NaN         False
# 1   [{'candidate': 'Nadeen Bir', 'votes': 296, 'sh...          True
# 2   [{'candidate': 'Nadeen Bir', 'votes': 53, 'sha...          True
# 3   [{'candidate': 'Nadeen Bir', 'votes': 110, 'sh...          True
# 4   [{'candidate': 'Nadeen Bir', 'votes': 342, 'sh...          True
# 5   [{'candidate': 'Nadeen Bir', 'votes': 307, 'sh...          True
# 6   [{'candidate': 'Nadeen Bir', 'votes': 325, 'sh...          True
# 7   [{'candidate': 'Nadeen Bir', 'votes': 276, 'sh...          True
# 8   [{'candidate': 'Nadeen Bir', 'votes': 118, 'sh...          True
# 9                                                 NaN         False
# 10  [{'candidate': 'Nadeen Bir', 'votes': 361, 'sh...          True
# 11                                                NaN         False
# 12                                                NaN         False
# 13  [{'candidate': 'Nadeen Bir', 'votes': 427, 'sh...          True
# 14  [{'candidate': 'Nadeen Bir', 'votes': 171, 'sh...          True
# 15                                                NaN         False
# 16                                                NaN         False
# 17  [{'candidate': 'Nadeen Bir', 'votes': 354, 'sh...          True
# 18                                                NaN         False
# 19                                                NaN         False
# 20  [{'candidate': 'Nadeen Bir', 'votes': 351, 'sh...          True
# 21                                                NaN         False
# 22  [{'candidate': 'Nadeen Bir', 'votes': 383, 'sh...          True
# 23                                                NaN         False
# 24                                                NaN         False
# 25                                                NaN         False
# 26                                                NaN         False
# 27                                                NaN         False
# 28  [{'candidate': 'Nadeen Bir', 'votes': 136, 'sh...          True
# 29                                                NaN         False
# 30                                                NaN         False
# 31                                                NaN         False
# 32                                                NaN         False
# 33                                                NaN         False
# 34                                                NaN         False
# 35                                                NaN         False
# 36                                                NaN         False
# 37  [{'candidate': 'Nadeen Bir', 'votes': 408, 'sh...          True
# 38  [{'candidate': 'Nadeen Bir', 'votes': 530, 'sh...          True
# 39  [{'candidate': 'Nadeen Bir', 'votes': 93, 'sha...          True
# 40  [{'candidate': 'Bettina Umstead', 'votes': 36,...          True
# 41                                                NaN         False
# 42                                                NaN         False
# 43  [{'candidate': 'Nadeen Bir', 'votes': 102, 'sh...          True
# 44                                                NaN         False
# 45                                                NaN         False
# 46                                                NaN         False
# 47                                                NaN         False
# 48                                                NaN         False
# 49                                                NaN         False
# 50                                                NaN         False
# 51                                                NaN         False
# 52                                                NaN         False
# 53                                                NaN         False
# 54                                                NaN         False
# 55                                                NaN         False
# 56                                                NaN         False
# 57                                                NaN         False
#
#          map_key                                           geometry
# 0            NaN  POLYGON ((-78.96129 35.91895, -78.96097 35.919...
# 1       DURHAM_7  POLYGON ((-78.91206 35.99693, -78.91228 35.996...
# 2      DURHAM_12  POLYGON ((-78.89242 35.97789, -78.89271 35.977...
# 3       DURHAM_1  POLYGON ((-78.90559 36.01104, -78.90561 36.009...
# 4       DURHAM_4  POLYGON ((-78.91894 36.02079, -78.91905 36.018...
# 5       DURHAM_2  POLYGON ((-78.9148 36.00344, -78.91518 36.0036...
# 6    DURHAM_34-1  POLYGON ((-78.909 35.92209, -78.90904 35.9222,...
# 7       DURHAM_3  POLYGON ((-78.91974 36.00746, -78.91982 36.005...
# 8       DURHAM_5  POLYGON ((-78.93562 35.99632, -78.93589 35.996...
# 9            NaN  POLYGON ((-78.93605 35.97704, -78.93674 35.975...
# 10      DURHAM_8  POLYGON ((-78.91206 35.98404, -78.91203 35.984...
# 11           NaN  POLYGON ((-78.88245 35.94388, -78.88243 35.944...
# 12           NaN  POLYGON ((-78.80602 35.92983, -78.80656 35.930...
# 13      DURHAM_9  POLYGON ((-78.93403 35.95785, -78.93378 35.958...
# 14     DURHAM_10  POLYGON ((-78.90062 35.97739, -78.90074 35.977...
# 15           NaN  POLYGON ((-78.85366 35.99739, -78.8538 35.9972...
# 16           NaN  POLYGON ((-78.87092 35.97387, -78.87078 35.973...
# 17     DURHAM_20  POLYGON ((-78.89239 36.00977, -78.89252 36.009...
# 18           NaN  POLYGON ((-78.85319 35.96473, -78.85384 35.964...
# 19           NaN  POLYGON ((-78.86479 35.98791, -78.8639 35.9869...
# 20     DURHAM_17  POLYGON ((-78.88854 35.98607, -78.88883 35.985...
# 21           NaN  POLYGON ((-78.87139 36.0041, -78.87163 36.0040...
# 22     DURHAM_21  POLYGON ((-78.90149 36.01683, -78.90172 36.016...
# 23           NaN  POLYGON ((-78.89042 36.01502, -78.89039 36.015...
# 24           NaN  POLYGON ((-78.94765 35.95836, -78.94767 35.958...
# 25           NaN  POLYGON ((-78.95379 36.02641, -78.95376 36.026...
# 26           NaN  POLYGON ((-78.92125 36.05742, -78.92147 36.057...
# 27           NaN  POLYGON ((-78.91691 36.02828, -78.91693 36.028...
# 28     DURHAM_42  POLYGON ((-78.8933 35.95987, -78.89218 35.9572...
# 29           NaN  POLYGON ((-78.8711 36.06879, -78.87004 36.0707...
# 30           NaN  POLYGON ((-78.85606 36.09969, -78.85545 36.098...
# 31           NaN  POLYGON ((-78.90577 36.13914, -78.90575 36.139...
# 32           NaN  POLYGON ((-78.99427 35.90766, -78.99426 35.907...
# 33           NaN  POLYGON ((-78.87733 35.95785, -78.87752 35.957...
# 34           NaN  POLYGON ((-78.86842 36.11234, -78.8687 36.1123...
# 35           NaN  POLYGON ((-78.86938 36.03335, -78.86847 36.034...
# 36           NaN  POLYGON ((-78.83105 35.98528, -78.83104 35.985...
# 37   DURHAM_34-2  POLYGON ((-78.92257 35.93546, -78.92255 35.935...
# 38     DURHAM_54  POLYGON ((-78.91312 35.90429, -78.91375 35.904...
# 39  DURHAM_55-11  POLYGON ((-78.9046 35.96666, -78.9054 35.96579...
# 40  DURHAM_55-49  POLYGON ((-78.90189 35.96963, -78.9018 35.9697...
# 41           NaN  POLYGON ((-78.9643 35.91826, -78.96482 35.9181...
# 42           NaN  POLYGON ((-78.92078 35.97643, -78.92097 35.976...
# 43     DURHAM_41  POLYGON ((-78.91038 35.95175, -78.91077 35.951...
# 44           NaN  POLYGON ((-79.00069 35.95293, -79.00064 35.953...
# 45           NaN  POLYGON ((-78.91413 36.09169, -78.91398 36.090...
# 46           NaN  POLYGON ((-78.91857 36.02685, -78.91833 36.026...
# 47           NaN  POLYGON ((-78.95838 36.00132, -78.95837 36.001...
# 48           NaN  POLYGON ((-78.92987 35.92372, -78.92991 35.923...
# 49           NaN  POLYGON ((-78.83131 35.98763, -78.83113 35.987...
# 50           NaN  POLYGON ((-78.99727 35.86405, -78.99902 35.863...
# 51           NaN  POLYGON ((-78.79545 35.97398, -78.79563 35.973...
# 52           NaN  POLYGON ((-78.78739 35.97575, -78.7867 35.9757...
# 53           NaN  POLYGON ((-78.86352 35.93986, -78.86336 35.939...
# 54           NaN  POLYGON ((-78.85167 35.90157, -78.85132 35.901...
# 55           NaN  POLYGON ((-78.92614 35.89253, -78.926 35.89252...
# 56           NaN  POLYGON ((-78.90505 35.90269, -78.90486 35.902...
# 57           NaN  POLYGON ((-78.92451 35.95823, -78.9243 35.9575...
