# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
RESULTS_FILE = (
    PROJECT_ROOT
    / "data"
    / "raw"
    / "results"
    / "nc_primary_election_results_pct_20260303_RAW.csv"
)

# %%
SHAPEFILE = (
    PROJECT_ROOT
    / "data"
    / "raw"
    / "geography"
    / "SBE_PRECINCTS_20251212"
    / "SBE_PRECINCTS_20251212.shp"
)

# %%
CROSSWALK_FILE = (
    PROJECT_ROOT
    / "data"
    / "crosswalks"
    / "precinct_crosswalk_2026.csv"
)

# %%
import pandas as pd

CROSSWALK_DF = pd.read_csv(CROSSWALK_FILE)

# %%
CROSSWALK_DF.columns.tolist()
# Out:
# ['county', 'results_precinct_id', 'geo_precinct_id', 'match_method']

# %%
contest_name="US SENATE (DEM)"

# %%
import pydash


WEB_FILE = (
    PROJECT_ROOT
    / "map"
    / "data"
    / f"{pydash.snake_case(contest_name)}.geojson"
)

# %%
CONTEST_SUMMARY_FILE = (
    PROJECT_ROOT
    / "data"
    / "processed"
    / f"{pydash.snake_case(contest_name)}_contest_summary.csv"
)

# %%
WEB_COLUMNS = [
    "county",
    "precinct",
    "enr_desc",
    "winner",
    "winner_votes",
    "winner_share",
    "runner_up",
    "runner_up_votes",
    "runner_up_share",
    "contest_votes",
    "margin_of_victory",
    "is_tie",
    "results",
    "participated",
    "map_key",
    "geometry"
]

# %%
from pipelines.statewide import build_statewide_map

# %%
web_precincts = build_statewide_map(
    results_file=RESULTS_FILE,
    geography_file=SHAPEFILE,
    crosswalk=CROSSWALK_DF,
    contest_name=contest_name,
    contest_summary_file=CONTEST_SUMMARY_FILE,
    output_file=WEB_FILE,
    web_columns=WEB_COLUMNS,
)

# %%
participated = web_precincts[
    web_precincts["participated"]
].copy()

west, south, east, north = participated.total_bounds

contest_bounds = [
    [west, south],
    [east, north]
]

print(contest_bounds)
# Out:
# [[np.float64(-84.3218209914704), np.float64(33.75287799999573)], [np.float64(-75.4001189911457), np.float64(36.588136999894786)]]

# %%
web_precincts
# Out:
#           county precinct        enr_desc      winner  winner_votes  \
# 0     ROCKINGHAM     LI-1       Lincoln-1  Roy Cooper           189
# 1     ROCKINGHAM       DR          Draper  Roy Cooper            98
# 2     ROCKINGHAM       RC    Rock Central  Roy Cooper           250
# 3     ROCKINGHAM     WS-1       Western-1  Roy Cooper           399
# 4     ROCKINGHAM       ST      Stoneville  Roy Cooper           279
# ...          ...      ...             ...         ...           ...
# 2627        WAKE    05-10           05-10  Roy Cooper           423
# 2628      PENDER     PL18       Penderlea  Roy Cooper           106
# 2629      PENDER     BW01          Burgaw  Roy Cooper           338
# 2630      PENDER     RP21     Rocky Point  Roy Cooper           356
# 2631      PENDER     MC07  Malpass Corner  Roy Cooper           220
#
#       winner_share           runner_up  runner_up_votes  runner_up_share  \
# 0        86.301370  Marcus W. Williams               13         5.936073
# 1        85.217391      Justin E. Dues                6         5.217391
# 2        85.324232  Marcus W. Williams               17         5.802048
# 3        88.079470  Marcus W. Williams               22         4.856512
# 4        89.423077  Marcus W. Williams               12         3.846154
# ...            ...                 ...              ...              ...
# 2627     93.171806      Justin E. Dues               17         3.744493
# 2628     81.538462  Marcus W. Williams               10         7.692308
# 2629     90.133333  Marcus W. Williams               13         3.466667
# 2630     89.000000  Marcus W. Williams               17         4.250000
# 2631     91.286307  Marcus W. Williams                8         3.319502
#
#       contest_votes  margin_of_victory  is_tie  \
# 0               219          80.365297   False
# 1               115          80.000000   False
# 2               293          79.522184   False
# 3               453          83.222958   False
# 4               312          85.576923   False
# ...             ...                ...     ...
# 2627            454          89.427313   False
# 2628            130          73.846154   False
# 2629            375          86.666667   False
# 2630            400          84.750000   False
# 2631            241          87.966805   False
#
#                                                 results  participated  \
# 0     [{'candidate': 'Roy Cooper', 'votes': 189, 'sh...          True
# 1     [{'candidate': 'Roy Cooper', 'votes': 98, 'sha...          True
# 2     [{'candidate': 'Roy Cooper', 'votes': 250, 'sh...          True
# 3     [{'candidate': 'Roy Cooper', 'votes': 399, 'sh...          True
# 4     [{'candidate': 'Roy Cooper', 'votes': 279, 'sh...          True
# ...                                                 ...           ...
# 2627  [{'candidate': 'Roy Cooper', 'votes': 423, 'sh...          True
# 2628  [{'candidate': 'Roy Cooper', 'votes': 106, 'sh...          True
# 2629  [{'candidate': 'Roy Cooper', 'votes': 338, 'sh...          True
# 2630  [{'candidate': 'Roy Cooper', 'votes': 356, 'sh...          True
# 2631  [{'candidate': 'Roy Cooper', 'votes': 220, 'sh...          True
#
#               map_key                                           geometry
# 0     ROCKINGHAM_LI-1  POLYGON ((-79.65716 36.3769, -79.65712 36.377,...
# 1       ROCKINGHAM_DR  POLYGON ((-79.71919 36.48737, -79.71858 36.487...
# 2       ROCKINGHAM_RC  POLYGON ((-79.76172 36.34849, -79.7624 36.3477...
# 3     ROCKINGHAM_WS-1  POLYGON ((-80.03242 36.35641, -80.03241 36.356...
# 4       ROCKINGHAM_ST  POLYGON ((-79.94013 36.44142, -79.94036 36.441...
# ...               ...                                                ...
# 2627       WAKE_05-10  POLYGON ((-78.87199 35.82074, -78.87206 35.820...
# 2628      PENDER_PL18  POLYGON ((-77.89829 34.60592, -77.90554 34.605...
# 2629      PENDER_BW01  POLYGON ((-77.84096 34.46559, -77.84089 34.465...
# 2630      PENDER_RP21  POLYGON ((-77.93499 34.35802, -77.9351 34.3580...
# 2631      PENDER_MC07  POLYGON ((-78.25607 34.39948, -78.25564 34.399...
#
# [2632 rows x 16 columns]
